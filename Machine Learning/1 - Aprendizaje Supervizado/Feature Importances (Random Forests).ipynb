# %% [markdown]
# # 🌳 Feature Importances
#
# En Random Forest de scikit-learn, `feature importances` se refiere a la **medida de la importancia relativa de cada característica en la predicción del resultado objetivo**.
#
# Esta medida se calcula durante el entrenamiento del modelo y puede ser accedida después de que el modelo ha sido ajustado.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
# Cargar el conjunto de datos Iris
iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names

# %%
# Entrenar un clasificador de Random Forest
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X, y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Obtener la importancia de las características
feature_importances = rf_classifier.feature_importances_

# %%
# Visualizar la importancia de las características
plt.figure(figsize=(5, 2.5))
plt.barh(range(len(feature_importances)), feature_importances, align='center')
plt.yticks(range(len(feature_importances)), feature_names)
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.show()
